# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('movie_collection.csv')
df.head(20)
# Out:
#     Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0        48000            20.1264               59.62               0.462
# 1        43200            20.5462               69.14               0.531
# 2        69400            20.5458               69.14               0.531
# 3        66800            20.6474               59.36               0.542
# 4        72400            21.3810               59.36               0.542
# 5        57400            20.5970               59.36               0.542
# 6        45800            21.7658               70.74               0.476
# 7        44200            22.8910               70.74               0.476
# 8        33000            24.2248               70.74               0.476
# 9        37800            23.4008               70.74               0.476
# 10       30000            24.4978               70.74               0.476
# 11       37800            22.3494               70.74               0.476
# ...

# %%
df.shape
# Out:
# (506, 20)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
df['Marketing expense'].unique()
# Out:
# array([  20.1264,   20.5462,   20.5458,   20.6474,   21.381 ,   20.597 ,
#          21.7658,   22.891 ,   24.2248,   23.4008,   24.4978,   22.3494,
#          21.8756,   32.5952,   32.7592,   32.5478,   41.0786,   35.684 ,
#          36.0542,   34.516 ,   45.0358,   37.0408,   44.6494,   39.7686,
#          35.0052,   36.8108,   33.4382,   39.1154,   35.4598,   40.049 ,
#          42.6162,   47.0944,   47.7598,   43.0344,   52.2564,   21.2834,
#          21.9488,   21.6028,   23.501 ,   20.5526,   20.6718,   22.5488,
#          22.83  ,   23.1872,   22.4538,   23.4284,   23.7672,   24.5854,
#          25.0774,   24.3954,   21.7746,   20.8674,   21.072 ,   20.9962,
#          20.272 ,   20.2622,   20.411 ,   20.2864,   23.089 ,   22.0656,
#          22.9864,   23.4342,   22.2054,   22.53  ,   20.3902,   20.7168,
#          20.8758,   21.1578,   22.7108,   22.5632,   21.7652,   23.1752,
#          21.8328,   23.9078,   21.5792,   21.9024,   22.0306,   21.7414,
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
sns.boxplot(df.Collection)
# Out:
# <Axes: >

# %%
sns.distplot(df.Collection)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4332\2449373221.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Collection)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Collection', ylabel='Density'>

# %%
help(sns.distplot)
# Out:
# Help on function distplot in module seaborn.distributions:
#
# distplot(a=None, bins=None, hist=True, kde=True, rug=False, fit=None, hist_kws=None, kde_kws=None, rug_kws=None, fit_kws=None, color=None, vertical=False, norm_hist=False, axlabel=None, label=None, ax=None, x=None)
#     DEPRECATED
#
#     This function has been deprecated and will be removed in seaborn v0.14.0.
#     It has been replaced by :func:`histplot` and :func:`displot`, two functions
#     with a modern API and many more capabilities.
#
#     For a guide to updating, please see this notebook:
#
#     https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
df.isnull().sum()
# Out:
# Collection              0
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# 3D_available            0
# Time_taken             12
# Twitter_hastags         0
# Genre                   0
# Avg_age_actors          0
# MPAA_film_rating        0
# Num_multiplex           0
# Start_Tech_Oscar        0
# dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
sns.boxplot(df.Budget)
# Out:
# <Axes: >

# %%
sns.jointplot(df.Budget)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(df.Movie_length  )
# Out:
# <Axes: >

# %%
sns.boxplot(df.Trailer_views)
# Out:
# <Axes: >

# %%
sns.boxplot(df.Time_taken)
# Out:
# <Axes: >

# %%
df.groupby(['Movie_length','Time_taken']).count()
# Out:
#                          Collection  Marketing expense  Production expense  \
# Movie_length Time_taken
# 76.4         154.64               1                  1                   1
# 79.5         157.64               1                  1                   1
# 79.7         119.36               1                  1                   1
# 80.0         121.88               1                  1                   1
# 80.1         162.12               1                  1                   1
# ...                             ...                ...                 ...
# 173.5        194.00               1                  1                   1
#              196.00               1                  1                   1
#              197.28               1                  1                   1
#              199.24               1                  1                   1
#              199.76               1                  1                   1
#
# ...

# %%
sns.jointplot(x='Start_Tech_Oscar', y='Trailer_views', data=df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(df.Start_Tech_Oscar)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
help(sns.jointplot)
# Out:
# Help on function jointplot in module seaborn.axisgrid:
#
# jointplot(data=None, *, x=None, y=None, hue=None, kind='scatter', height=6, ratio=5, space=0.2, dropna=False, xlim=None, ylim=None, color=None, palette=None, hue_order=None, hue_norm=None, marginal_ticks=False, joint_kws=None, marginal_kws=None, **kwargs)
#     Draw a plot of two variables with bivariate and univariate graphs.
#
#     This function provides a convenient interface to the :class:`JointGrid`
#     class, with several canned plot kinds. This is intended to be a fairly
#     lightweight wrapper; if you need more flexibility, you should use
#     :class:`JointGrid` directly.
#
#     Parameters
#     ----------
#     data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#         Input data structure. Either a long-form collection of vectors that can be
#         assigned to named variables or a wide-form dataset that will be internally
#         reshaped.
# ...

# %%
sns.countplot(x='3D_available', data=df)
sns.countplot(x='Genre',data=df)
# Out:
# <Axes: xlabel='Genre', ylabel='count'>

# %%
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
df[df['Avg_age_actors']>20]
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 500       33600            24.4876               74.38               0.415
# 501       44800            21.2526               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
sns.distplot(df.Avg_age_actors)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4332\73492647.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Avg_age_actors)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Avg_age_actors', ylabel='Density'>

# %%
df = df[df['Movie_length'] < 100]

# %%
df['Average expense'] = (df['Marketing expense'] + df['Production expense']) / 2

# %%
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 39        61600            20.5526               60.90              0.5720
# 40        69800            20.6718               60.90              0.5720
# 41        53200            22.5488               68.82              0.5520
# 42        50600            22.8300               68.82              0.5520
# 43        49400            23.1872               68.82              0.5520
# 52        50000            21.0720               66.28              0.5610
# 53        46800            20.9962               66.28              0.5610
# 55        70800            20.2622               57.44              0.5970
# 65        47000            20.7168               61.74              0.6020
# 67        44000            21.1578               67.14              0.5910
# 70        48400            21.7652               76.62              0.5870
# ...

# %%
df.drop(columns=['Marketing expense', 'Production expense'], inplace=True)

# %%
df
# Out:
#      Collection  Multiplex coverage     Budget  Movie_length  \
# 39        61600              0.5720  36635.225          95.3
# 40        69800              0.5720  39018.320          89.3
# 41        53200              0.5520  37607.350          76.4
# 42        50600              0.5520  34268.795          80.1
# 43        49400              0.5520  34502.105          80.0
# 52        50000              0.5610  36168.605          94.6
# 53        46800              0.5610  33318.890          94.9
# 55        70800              0.5970  40268.195          95.4
# 65        47000              0.6020  34940.950          91.3
# 67        44000              0.5910  32652.290          94.9
# 70        48400              0.5870  35646.435          80.1
# 71        43400              0.5870  33113.355          91.0
# 72        45600              0.5870  33691.075          81.3
# 73        46800              0.5870  34690.975          79.7
# ...

# %%
df['Average rating'] = (df['Lead_ Actor_Rating'] + df['Lead_Actress_rating'] + df['Director_rating'] + df['Producer_rating'] + df['Critic_rating']) / 5

# %%
df
# Out:
#      Collection  Multiplex coverage     Budget  Movie_length  \
# 39        61600              0.5720  36635.225          95.3
# 40        69800              0.5720  39018.320          89.3
# 41        53200              0.5520  37607.350          76.4
# 42        50600              0.5520  34268.795          80.1
# 43        49400              0.5520  34502.105          80.0
# 52        50000              0.5610  36168.605          94.6
# 53        46800              0.5610  33318.890          94.9
# 55        70800              0.5970  40268.195          95.4
# 65        47000              0.6020  34940.950          91.3
# 67        44000              0.5910  32652.290          94.9
# 70        48400              0.5870  35646.435          80.1
# 71        43400              0.5870  33113.355          91.0
# 72        45600              0.5870  33691.075          81.3
# 73        46800              0.5870  34690.975          79.7
# ...

# %%
df.drop(columns= ['Lead_ Actor_Rating' ,'Lead_Actress_rating','Director_rating','Producer_rating','Critic_rating'],inplace=True)

# %%
df
# Out:
#      Collection  Multiplex coverage     Budget  Movie_length  Trailer_views  \
# 39        61600              0.5720  36635.225          95.3         553070
# 40        69800              0.5720  39018.320          89.3         567784
# 41        53200              0.5520  37607.350          76.4         512492
# 42        50600              0.5520  34268.795          80.1         526836
# 43        49400              0.5520  34502.105          80.0         473146
# 52        50000              0.5610  36168.605          94.6         504792
# 53        46800              0.5610  33318.890          94.9         496877
# 55        70800              0.5970  40268.195          95.4         512329
# 65        47000              0.6020  34940.950          91.3         545499
# 67        44000              0.5910  32652.290          94.9         493569
# 70        48400              0.5870  35646.435          80.1         501152
# ...

# %%
df=pd.get_dummies(df)

# %%
df
# Out:
#      Collection  Multiplex coverage     Budget  Movie_length  Trailer_views  \
# 39        61600              0.5720  36635.225          95.3         553070
# 40        69800              0.5720  39018.320          89.3         567784
# 41        53200              0.5520  37607.350          76.4         512492
# 42        50600              0.5520  34268.795          80.1         526836
# 43        49400              0.5520  34502.105          80.0         473146
# 52        50000              0.5610  36168.605          94.6         504792
# 53        46800              0.5610  33318.890          94.9         496877
# 55        70800              0.5970  40268.195          95.4         512329
# 65        47000              0.6020  34940.950          91.3         545499
# 67        44000              0.5910  32652.290          94.9         493569
# 70        48400              0.5870  35646.435          80.1         501152
# ...

# %%
df.fillna(df['Time_taken'].median())
# Out:
#      Collection  Multiplex coverage     Budget  Movie_length  Trailer_views  \
# 39        61600              0.5720  36635.225          95.3         553070
# 40        69800              0.5720  39018.320          89.3         567784
# 41        53200              0.5520  37607.350          76.4         512492
# 42        50600              0.5520  34268.795          80.1         526836
# 43        49400              0.5520  34502.105          80.0         473146
# 52        50000              0.5610  36168.605          94.6         504792
# 53        46800              0.5610  33318.890          94.9         496877
# 55        70800              0.5970  40268.195          95.4         512329
# 65        47000              0.6020  34940.950          91.3         545499
# 67        44000              0.5910  32652.290          94.9         493569
# 70        48400              0.5870  35646.435          80.1         501152
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 39 to 355
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Collection           51 non-null     int64
#  1   Multiplex coverage   51 non-null     float64
#  2   Budget               51 non-null     float64
#  3   Movie_length         51 non-null     float64
#  4   Trailer_views        51 non-null     int64
#  5   Time_taken           51 non-null     float64
#  6   Twitter_hastags      51 non-null     float64
#  7   Avg_age_actors       51 non-null     int64
#  8   Num_multiplex        51 non-null     int64
#  9   Start_Tech_Oscar     51 non-null     int64
#  10  Average expense      51 non-null     float64
#  11  Average rating       51 non-null     float64
#  12  3D_available_NO      51 non-null     bool
#  13  3D_available_YES     51 non-null     bool
#  14  Genre_Action         51 non-null     bool
# ...

# %%
df.shape
# Out:
# (51, 19)

# %%
sns.boxplot(x=df['Twitter_hastags'])
# Out:
# <Axes: xlabel='Twitter_hastags'>
