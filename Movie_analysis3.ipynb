# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('movie_collection.csv')
df.head(20)
# Out:
#     Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0        48000            20.1264               59.62               0.462
# 1        43200            20.5462               69.14               0.531
# 2        69400            20.5458               69.14               0.531
# 3        66800            20.6474               59.36               0.542
# 4        72400            21.3810               59.36               0.542
# 5        57400            20.5970               59.36               0.542
# 6        45800            21.7658               70.74               0.476
# 7        44200            22.8910               70.74               0.476
# 8        33000            24.2248               70.74               0.476
# 9        37800            23.4008               70.74               0.476
# 10       30000            24.4978               70.74               0.476
# 11       37800            22.3494               70.74               0.476
# ...

# %%
import statsmodels.api as sm
import statsmodels.api as sn
from sklearn.linear_model import LogisticRegression

# %%
df['Budget'].unique()
# Out:
# array([36524.125, 35668.655, 39912.675, 38873.89 , 39701.585, 35718.65 ,
#        33396.66 , 34285.46 , 31280.205, 33352.22 , 35424.235, 33379.995,
#        32713.395, 33046.695, 33863.28 , 32407.87 , 32968.925, 33274.45 ,
#        30308.08 , 31813.485, 30941.35 , 33135.575, 34118.81 , 32291.215,
#        32907.82 , 31102.445, 33591.085, 36079.725, 37074.07 , 31735.715,
#        33729.96 , 33052.25 , 31669.055, 32957.815, 32446.755, 32496.75 ,
#        33141.13 , 36635.225, 39018.32 , 37607.35 , 34268.795, 34502.105,
#        33713.295, 31563.51 , 32141.23 , 33496.65 , 29991.445, 31119.11 ,
#        33124.465, 33968.825, 36168.605, 33318.89 , 32707.84 , 40268.195,
#        35457.565, 37862.88 , 34135.475, 32924.485, 31891.255, 35863.08 ,
#        37562.91 , 39462.72 , 34940.95 , 32146.785, 32652.29 , 31074.67 ,
#        32691.175, 35646.435, 33113.355, 33691.075, 34690.975, 34846.515,
#        34918.73 , 34879.845, 34107.7  , 34618.76 , 32630.07 , 37368.485,
# ...

# %%
df['Start_Tech_Oscar'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
z = df[['Budget']].values
y = df['Start_Tech_Oscar'].values

# Create and fit the logistic regression model
model = LogisticRegression()
model.fit(z, y)
# Out:
# LogisticRegression()

# %%
correlation = df['Budget'].corr(df['Start_Tech_Oscar'])

# %%
correlation
# Out:
# 0.027147653515770042

# %%
z_const=sn.add_constant(z)

# %%
z_const
# Out:
# array([[1.0000000e+00, 3.6524125e+04],
#        [1.0000000e+00, 3.5668655e+04],
#        [1.0000000e+00, 3.9912675e+04],
#        ...,
#        [1.0000000e+00, 3.8751680e+04],
#        [1.0000000e+00, 3.7740670e+04],
#        [1.0000000e+00, 3.3496650e+04]])

# %%
import statsmodels.discrete.discrete_model as sm

# %%
log = sm.Logit(y,z_const).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.688641
#          Iterations 4

# %%
log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                      y   No. Observations:                  506
# Model:                          Logit   Df Residuals:                      504
# Method:                           MLE   Df Model:                            1
# Date:                Tue, 06 Aug 2024   Pseudo R-squ.:               0.0005348
# Time:                        11:41:51   Log-Likelihood:                -348.45
# converged:                       True   LL-Null:                       -348.64
# Covariance Type:            nonrobust   LLR p-value:                    0.5414
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6707      0.805     -0.833      0.405      -2.249       0.908
# x1          1.399e-05   2.29e-05      0.610      0.542   -3.09e-05    5.89e-05
# ...

# %%
df = pd.get_dummies(df)
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
for col in df.columns:
    if df[col].dtype == bool:
        df[col] = df[col].astype(int)
print(df)
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
df
# Out:
#      Collection  Marketing expense  Production expense  Multiplex coverage  \
# 0         48000            20.1264               59.62               0.462
# 1         43200            20.5462               69.14               0.531
# 2         69400            20.5458               69.14               0.531
# 3         66800            20.6474               59.36               0.542
# 4         72400            21.3810               59.36               0.542
# ..          ...                ...                 ...                 ...
# 501       44800            21.2526               78.86               0.427
# 502       41200            20.9054               78.86               0.427
# 503       47800            21.2152               78.86               0.427
# 504       44000            22.1918               78.86               0.427
# 505       38000            20.9482               78.86               0.427
#
# ...

# %%
from sklearn.impute import SimpleImputer
p = df.loc[:,df.columns != 'Start_Tech_Oscar']
k = df['Start_Tech_Oscar'].values
imputer = SimpleImputer(strategy='mean')
p = imputer.fit_transform(p)

# %%
model = LogisticRegression()
model.fit(p, k)
# Out:
# C:\Users\ANISHKA\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
correlation = df.corr()
cor = correlation['Start_Tech_Oscar']
cor
# Out:
# Collection            -0.154698
# Marketing expense      0.013417
# Production expense     0.024404
# Multiplex coverage     0.004017
# Budget                 0.027148
# Movie_length          -0.016291
# Lead_ Actor_Rating     0.035309
# Lead_Actress_rating    0.040356
# Director_rating        0.035768
# Producer_rating        0.043612
# Critic_rating          0.001084
# Trailer_views          0.075783
# Time_taken             0.064536
# Twitter_hastags       -0.077333
# Avg_age_actors        -0.040581
# Num_multiplex          0.004857
# Start_Tech_Oscar       1.000000
# 3D_available_NO        0.070371
# 3D_available_YES      -0.070371
# Genre_Action          -0.003117
# Genre_Comedy          -0.021134
# Genre_Drama           -0.061414
# Genre_Thriller         0.072842
# MPAA_film_rating_PG         NaN
# Name: Start_Tech_Oscar, dtype: float64

# %%
p_const = sn.add_constant(p)

# %%
p_const
# Out:
# array([[4.80000e+04, 2.01264e+01, 5.96200e+01, ..., 0.00000e+00,
#         1.00000e+00, 1.00000e+00],
#        [4.32000e+04, 2.05462e+01, 6.91400e+01, ..., 1.00000e+00,
#         0.00000e+00, 1.00000e+00],
#        [6.94000e+04, 2.05458e+01, 6.91400e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.00000e+00],
#        ...,
#        [4.78000e+04, 2.12152e+01, 7.88600e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.00000e+00],
#        [4.40000e+04, 2.21918e+01, 7.88600e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.00000e+00],
#        [3.80000e+04, 2.09482e+01, 7.88600e+01, ..., 0.00000e+00,
#         0.00000e+00, 1.00000e+00]])
